# %% [markdown]
# # 面向对象 (OOP) 高级特性实战
#
# > 本 Notebook 展示了 Python 中的多继承 MRO、抽象基类 (ABC) 以及使用 `__slots__` 进行内存优化的技巧。

# %% [markdown]
# ## 1. 多继承与 MRO (C3 线性化)
# 展示钻石继承下的方法查找顺序。

# %%
class A: pass
class B(A): pass
class C(A): pass
class D(B, C): pass

print(f"MRO of D: {[cls.__name__ for cls in D.mro()]}")

# %% [markdown]
# ## 2. 抽象基类 (ABC)
# 定义接口规范并强制子类实现。

# %%
from abc import ABC, abstractmethod

class Plugin(ABC):
    @abstractmethod
    def run(self):
        pass

try:
    p = Plugin()
except TypeError as e:
    print(f"Enforcement works: {e}")

# %% [markdown]
# ## 3. 内存优化 (__slots__)
# 对比传统实例与使用 `__slots__` 实例的差异。

# %%
class Point:
    __slots__ = ('x', 'y')
    def __init__(self, x, y):
        self.x = x
        self.y = y

p = Point(1, 2)
print(f"Point: ({p.x}, {p.y})")
try:
    p.z = 3
except AttributeError as e:
    print(f"__slots__ prevents dynamic dict: {e}")
